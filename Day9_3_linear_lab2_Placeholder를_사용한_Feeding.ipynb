# %% [markdown]
# <a href="https://colab.research.google.com/github/DionKimmm/2019SummerML/blob/master/Day9_3_linear_lab2_Placeholder%EB%A5%BC_%EC%82%AC%EC%9A%A9%ED%95%9C_Feeding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
X = tf.placeholder(tf.float32, shape=[None])
Y = tf.placeholder(tf.float32, shape=[None]) # None의 의미 : 몇 개가 들어오든 맞춰 주겠다는 뜻 (없다는 뜻이 아님)
print(X, Y)
# Out:
# Tensor("Placeholder:0", shape=(?,), dtype=float32) Tensor("Placeholder_1:0", shape=(?,), dtype=float32)

# %%
W = tf.Variable(tf.random_normal([1]))
b = tf.Variable(tf.random_normal([1]))

# %%
hypothesis = X * W + b

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)

# %%
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(2001):
  # Unpacking 
  cost_val, W_val, b_val, _ = sess.run([cost, W, b, train], feed_dict={X: [1, 2, 3, 4, 5], Y: [2.1, 3.1, 4.1, 5.1, 6.1]})
  
  # train은 필요 없다는 뜻으로 _를 넣음. 
  # train은 필요 없고 우리의 목표는 cost를 줄이는 것이다.
  if step % 20 == 0:
    print(cost_val, W_val, b_val)

    # 이해할 필요가 없다, 쓰면 된다.
# Out:
# 0.026800752 [1.0901321] [0.8852692]
# 0.00793152 [1.0577515] [0.89199823]
# 0.0069263442 [1.0538498] [0.9055873]
# 0.0060488265 [1.0503224] [0.9183195]
# 0.005282485 [1.0470269] [0.930218]
# 0.004613221 [1.043947] [0.9413372]
# 0.00402877 [1.0410688] [0.95172817]
# 0.0035183437 [1.0383792] [0.96143866]
# 0.003072594 [1.0358657] [0.9705132]
# 0.002683314 [1.0335169] [0.9789934]
# 0.0023433683 [1.0313219] [0.98691815]
# 0.002046482 [1.0292704] [0.994324]
# 0.001787192 [1.0273536] [1.0012449]
# 0.0015607795 [1.0255623] [1.0077122]
# 0.0013630468 [1.0238881] [1.0137562]
# 0.0011903446 [1.0223236] [1.0194048]
# 0.0010395305 [1.0208615] [1.024683]
# 0.000907832 [1.0194952] [1.0296155]
# 0.00079281314 [1.0182185] [1.0342251]
# 0.0006923716 [1.0170254] [1.0385327]
# 0.00060466124 [1.0159104] [1.0425583]
# 0.0005280462 [1.0148684] [1.0463203]
# 0.00046114583 [1.0138947] [1.0498359]
# 0.00040272297 [1.0129846] [1.0531212]
# 0.00035169892 [1.0121343] [1.0561914]
# ...
